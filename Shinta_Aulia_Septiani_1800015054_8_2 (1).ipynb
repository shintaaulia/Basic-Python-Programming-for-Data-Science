# %% [markdown]
# ##**SHINTA AULIA SEPTIANI - 1800015054**

# %%
import plotly.express as px
import plotly.graph_objects as go
import numpy as np
import pandas as pd

# %% [markdown]
# #SAHAM JPFA

# %%
df1 = pd.read_csv("/content/JPFA.JK.csv")
df1
# Out:
#            Date    Open    High     Low   Close    Adj Close     Volume
# 0    2020-03-13  1200.0  1200.0  1200.0  1200.0  1158.248901          0
# 1    2020-03-16  1200.0  1200.0  1200.0  1200.0  1158.248901          0
# 2    2020-03-17  1040.0  1040.0  1005.0  1005.0   970.033447    6460200
# 3    2020-03-18  1005.0  1005.0   935.0   935.0   902.468933   15773500
# 4    2020-03-19   875.0   880.0   870.0   870.0   839.730408    3916300
# ..          ...     ...     ...     ...     ...          ...        ...
# 234  2021-03-05  1560.0  1665.0  1535.0  1645.0  1614.677490   72828200
# 235  2021-03-08  1665.0  1715.0  1660.0  1695.0  1663.755859   45827000
# 236  2021-03-09  1695.0  1845.0  1690.0  1790.0  1757.004639  117836000
# 237  2021-03-10  1800.0  1825.0  1740.0  1790.0  1757.004639   33114300
# 238  2021-03-12  1810.0  1890.0  1800.0  1850.0  1815.898682   34717600
#
# [239 rows x 7 columns]

# %%
#Scatter plot

fig = px.scatter(x=df1["Date"], y=df1["Close"], labels={'x':'Tanggal', 'y':'Harga Saham'})
fig.update_layout(title='SAHAM JPFA')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2ac17d85-34f7-4db8-8801-6d4320438608" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2ac17d85-34f7-4db8-8801-6d4320438608")) {
#                     Plotly.newPlot(
#                         '2ac17d85-34f7-4db8-8801-6d4320438608',
# ...

# %%
#LINE MARKERS
fig = go.Figure()
fig = go.Figure(data=go.Scatter(x=df2['Date'], y=df2['Close'], mode='lines+markers'))
fig.update_layout(title='SAHAM JPFA')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3318e519-a2d3-4b55-acd1-5e22be344fd9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3318e519-a2d3-4b55-acd1-5e22be344fd9")) {
#                     Plotly.newPlot(
#                         '3318e519-a2d3-4b55-acd1-5e22be344fd9',
# ...

# %% [markdown]
# #SAHAM INCO

# %%
df2 = pd.read_csv("/content/INCO.JK.csv")
df2
# Out:
#            Date    Open    High     Low   Close    Adj Close     Volume
# 0    2020-03-13  1930.0  1930.0  1930.0  1930.0  1912.100220          0
# 1    2020-03-16  1880.0  1880.0  1780.0  1780.0  1763.491455    4016600
# 2    2020-03-17  1780.0  1780.0  1660.0  1660.0  1644.604370    3715000
# 3    2020-03-18  1650.0  1650.0  1545.0  1545.0  1530.670898    4857000
# 4    2020-03-19  1440.0  1440.0  1440.0  1440.0  1426.644775    2047900
# ..          ...     ...     ...     ...     ...          ...        ...
# 234  2021-03-05  5150.0  5400.0  5150.0  5150.0  5102.236328  101200300
# 235  2021-03-08  5200.0  5275.0  4800.0  4830.0  4785.204102   77938000
# 236  2021-03-09  4800.0  4810.0  4510.0  4550.0  4507.801270  113826500
# 237  2021-03-10  4580.0  4640.0  4460.0  4530.0  4487.986816   48612700
# 238  2021-03-12  4620.0  4820.0  4580.0  4640.0  4596.966309  104333100
#
# [239 rows x 7 columns]

# %%
#SCATTER PLOT
fig = px.scatter(x=df2["Date"], y=df2["Close"], labels={'x':'Tanggal', 'y':'Harga Saham'})
fig.update_layout(title='SAHAM INCO')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="fb02dc20-e2a3-4a52-b77e-f4f5ee7e78bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fb02dc20-e2a3-4a52-b77e-f4f5ee7e78bb")) {
#                     Plotly.newPlot(
#                         'fb02dc20-e2a3-4a52-b77e-f4f5ee7e78bb',
# ...

# %%
#LINES MARKERS

fig = go.Figure(data=go.Scatter(x=df2['Date'], y=df2['Close'], mode='lines+markers'))
fig.update_layout(title='SAHAM INCO')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3ce1eff0-bd75-434f-94e4-e8e70b065581" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3ce1eff0-bd75-434f-94e4-e8e70b065581")) {
#                     Plotly.newPlot(
#                         '3ce1eff0-bd75-434f-94e4-e8e70b065581',
# ...

# %% [markdown]
# #SAHAM BBCA

# %%
df3 = pd.read_csv("/content/PTBA.JK.csv")
df3
# Out:
#            Date    Open    High     Low   Close    Adj Close    Volume
# 0    2020-03-13  2060.0  2060.0  2060.0  2060.0  1731.289063         0
# 1    2020-03-16  2060.0  2060.0  2060.0  2060.0  1731.289063         0
# 2    2020-03-17  1835.0  1850.0  1710.0  1710.0  1437.138062  23282900
# 3    2020-03-18  1710.0  1710.0  1595.0  1595.0  1340.488281  29978700
# 4    2020-03-19  1590.0  1590.0  1485.0  1485.0  1248.040894   2795600
# ..          ...     ...     ...     ...     ...          ...       ...
# 234  2021-03-05  2680.0  2710.0  2670.0  2710.0  2627.714844  19286700
# 235  2021-03-08  2730.0  2740.0  2680.0  2680.0  2598.625732  18341300
# 236  2021-03-09  2680.0  2700.0  2580.0  2610.0  2530.751221  28531500
# 237  2021-03-10  2650.0  2650.0  2580.0  2600.0  2521.054688  16141100
# 238  2021-03-12  2650.0  2740.0  2630.0  2730.0  2647.107422  45093100
#
# [239 rows x 7 columns]

# %%
#SCATTER PLOT
fig = px.scatter(x=df3["Date"], y=df3["Close"], labels={'x':'Tanggal', 'y':'Harga Saham'})
fig.update_layout(title='SAHAM PTBA')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="87222f71-4392-4ad6-a701-9ff8f43011da" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("87222f71-4392-4ad6-a701-9ff8f43011da")) {
#                     Plotly.newPlot(
#                         '87222f71-4392-4ad6-a701-9ff8f43011da',
# ...

# %% [markdown]
# #GABUNG PLOT SAHAM JPFA, INCO DAN PTBA

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df1['Date'], y=df1['Close'], 
                    mode='lines', name='JPFA'))
fig.add_trace(go.Scatter(x=df2['Date'], y=df2['Close'], 
                    mode='lines', name='INCO'))
fig.add_trace(go.Scatter(x=df3['Date'], y=df3['Close'], 
                    mode='lines', name='PTBA'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6e32c35a-15e2-46b4-a7c4-809457807c59" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6e32c35a-15e2-46b4-a7c4-809457807c59")) {
#                     Plotly.newPlot(
#                         '6e32c35a-15e2-46b4-a7c4-809457807c59',
# ...
