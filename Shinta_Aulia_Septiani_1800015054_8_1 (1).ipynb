# %% [markdown]
# #**SHINTA AULIA SEPTIANI - 1800015054**

# %% [markdown]
# Buatlah plot dengan hasil output seperti pada gambar terlampir! File berbentuk Python notebook.

# %% [markdown]
# ![Tugas MatPlotlib.png](data:image/png;base64,...)

# %%
# %matplotlib inline

# %%
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.2.2
# 1.19.5

# %%
fig = plt.figure(figsize=(10,7))

ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

ax1.set_title('Sine Function')
ax2.set_title('Cosine Function')
ax3.set_title('Tangent Function')
ax4.set_title('Tanh Function')

x = np.arange(0, 2*np.pi, 0.05)

y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)
y4 = np.tanh(x)

ax1.plot(x,y1)
ax2.plot(x,y2)
ax3.plot(x,y3)
ax4.plot(x,y4)

plt.show()
